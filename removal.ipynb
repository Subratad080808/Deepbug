# %%
import pandas as pd
import numpy as np

# %%
wp=pd.read_csv('alldata_positive_done.csv')

# %%
wp
# Out:
#         Unnamed: 0 MethodName  \
# 0                0   patterns
# 1                1   patterns
# 2                2   patterns
# 3                3   patterns
# 4                4   register
# ...            ...        ...
# 243519       34844   property
# 243520       34845   property
# 243521       34846   property
# 243522       34885   property
# 243523       34886   property
#
#                                                M_Call_Arg  M_D_Name  \
# 0        ; <class 'str'>, , , , , , , , , , , , , , , ...  patterns
# 1       django.contrib.auth.views ; <class 'str'>, , L...  patterns
# 2                                     ; <class 'str'>, ,   patterns
# 3                                     ; <class 'str'>, ,   patterns
# 4       project_details ; <class 'str'>, ProjectDetail...  register
# ...                                                   ...       ...
# 243519  _get_cascade ; <class 'str'>, _set_cascade ; <...  property
# ...

# %%
wr=wp.dropna()

# %%
wr
# Out:
#         Unnamed: 0 MethodName  \
# 4                4   register
# 5                5   register
# 6                6   register
# 7                7   register
# 8                8   register
# ...            ...        ...
# 243519       34844   property
# 243520       34845   property
# 243521       34846   property
# 243522       34885   property
# 243523       34886   property
#
#                                                M_Call_Arg  M_D_Name  \
# 4       project_details ; <class 'str'>, ProjectDetail...  register
# 5       project_details ; <class 'str'>, ProjectDetail...  register
# 6       project_details ; <class 'str'>, ProjectDetail...  register
# 7       project_details ; <class 'str'>, ProjectDetail...  register
# 8       project_details ; <class 'str'>, ProjectDetail...  register
# ...                                                   ...       ...
# 243519  _get_cascade ; <class 'str'>, _set_cascade ; <...  property
# ...

# %%
wrrt=wr[['M_D_Name','M_D_Arg1','M_D_Arg2','MethodName','M_Call_Arg1','M_Call_Type1','M_Call_Arg2','M_Call_Type2']]

# %%
wrrt['class']='1'
# Out:
# C:\Users\sdas1\AppData\Local\Temp/ipykernel_5512/71976591.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wrrt['class']='1'

# %%
wrrt
# Out:
#         M_D_Name M_D_Arg1             M_D_Arg2 MethodName      M_Call_Arg1  \
# 4       register   'self'           'observer'   register  project_details
# 5       register   'self'               'func'   register  project_details
# 6       register  'klass'               'name'   register  project_details
# 7       register   'self'      'registry_name'   register  project_details
# 8       register   'self'  'model_or_iterable'   register  project_details
# ...          ...      ...                  ...        ...              ...
# 243519  property   'self'               'name'   property     _get_cascade
# 243520  property   'self'               'name'   property             bind
# 243521  property   'self'               'name'   property             bind
# 243522  property   'self'               'name'   property             bind
# 243523  property   'self'               'name'   property             bind
#
#          M_Call_Type1           M_Call_Arg2   M_Call_Type2 class
# ...

# %%
# Out:
# 'D:\\Testing\\adlibre\\Adlibre-TMS\\adlibre_tms\\apps\\tms\\reports.py'

# %%
wr[['M_D_Name','M_D_Arg1','M_D_Arg2','MethodName','M_Call_Arg1','M_Call_Type1','M_Call_Arg2','M_Call_Type2']]
